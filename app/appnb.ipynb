# %%
import re
from flask import Flask, request, json
from keras.preprocessing import text, sequence
from pathlib import Path
import tensorflow as tf
import os

app = Flask(__name__)

# model = tf.keras.models.load_model(str(Path().absolute())+'\\api-v1')

# model = tf.keras.models.load_model('D:\Project\Python\Data\\verifIDNews-api\\api-v1')

@app.route('/')
def home():
    return 'Wellcome to verifIDNews'

@app.route('/predict' ,methods=['POST'])
def predict():
    user_input = [request.form.get('input')]
    # model = keras.models.load_model(str(os.path.dirname(__file__))+ '/api_model.h5')
    # model = pickle.load(open(str(os.path.dirname(__file__))+ '\\api-v1', 'rb'))
    # path = str(os.path.dirname(__file__)) + '\\..\\api-v1'
    model= tf.keras.models.load_model('D:\Project\Python\Data\\verifIDNews-api\\api-v1')
    max_features = 10000
    maxlen = 300
        
    tokenizer = text.Tokenizer(num_words = max_features)
    tokenized_test = tokenizer.texts_to_sequences(user_input)
    user_input_tokenized = sequence.pad_sequences(tokenized_test, maxlen = maxlen)
    output = model.predict(user_input_tokenized)
    
    output = output[0][0]
        
    label = ''
        
    if output > 0.75 : 
        label = 'Berita Terindikasi sebagai Fakta'
    elif output <= 0.75 and output > 0.60 : 
        label = 'Berita Terindikasi lemah Fakta'
    elif output <= 0.6 and output > 0.5 :
        label = 'Berita perlu ditinjau ulang antara Fakta atau Hoax'
    elif output <= 0.5 and output > 0.35 : 
        label = 'Berita Terindikasi Lemah sebagai Hoax'
    elif output <= 0.35 and output > 0.15 : 
        label = 'Berita Terindikasi sebagai Hoax'
    elif output <= 0.15 :
        label = 'Berita Terindikasi Kuat sebagai Hoax'
        
    
    response = app.response_class(
        response= json.dumps({'indicator': str(output),'msg' : label }),
        status=200,
        mimetype='application/json'
    )
    
    return response


if __name__ == "__main__":
        app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/May/2022 17:09:00] "POST /predict HTTP/1.1" 200 -

# %%
import tkinter
import tkinter as tk
from tkinter.constants import BOTH, BOTTOM, CENTER, E, END, LEFT, RIGHT, TOP, W, Y, YES
from typing import Text

#deklarasi nilai P|C pada parameter 1/perilaku seks
p1_beresiko_ya = 0.947368421
p1_beresiko_tidak = 1
p1_tidakberesiko_ya = 0.052631579
p1_tidakberesiko_tidak = 0

#deklarasi nilai P|C pada parameter 2/kebiasaan makan
p2_beresiko_ya = 1
p2_beresiko_tidak = 0.791666667
p2_kurangberesiko_ya = 0
p2_kurangberesiko_tidak = 0.1875
p2_tidakberesiko_ya = 0
p2_tidakberesiko_tidak = 0.020833333

#deklarasi nilai P|C pada parameter 3/kebiasaan hidup higenis
p3_ya_ya = 0.853932584
p3_ya_tidak = 0.729166667
p3_kurang_ya = 0.123595506
p3_kurang_tidak = 0.229166667
p3_tidak_ya = 0.02247191
p3_tidak_tidak = 0.041666667

#deklarasi nilai P|C pada parameter 4/agregasi niat
p4_tinggi_ya = 0.789473684
p4_tinggi_tidak = 0.875
p4_rendah_ya = 0.210526316
p4_rendah_tidak = 0.125

#deklarasi nilai P|C pada parameter 5/komitmen niat
p5_baik_ya = 0.842105263
p5_baik_tidak = 0.916666667
p5_kurang_ya = 0.157894737
p5_kurang_tidak = 0.083333333
p5_rendah_ya = 0
p5_rendah_tidak = 0

#deklarasi nilai P|C pada parameter 6/konsistensi sikap
p6_baik_ya = 0.947368421
p6_baik_tidak = 0.875
p6_buruk_ya = 0.052631579
p6_buruk_tidak = 0.125

#deklarasi nilai P|C pada parameter 7/sikap spontanitas
p7_baik_ya = 1
p7_baik_tidak = 0.958333333
p7_buruk_ya = 0
p7_buruk_tidak = 0.041666667

#deklarasi nilai P|C pada parameter 8/kepentingan norma
p8_tinggi_ya =  0.315789474
p8_tinggi_tidak = 0.708333333
p8_rendah_ya =  0.684210526
p8_rendah_tidak = 0.291666667

#deklarasi nilai P|C pada parameter 9/pemenuhan norma
p9_baik_ya = 0.052631579
p9_baik_tidak = 0.625
p9_cukup_ya =  0.263157895
p9_cukup_tidak = 0.041666667
p9_kurang_ya =  0.684210526
p9_kurang_tidak =  0.333333333

#deklarasi nilai P|C pada parameter 10/kerentanan persepsi
p10_rentan_ya = 0
p10_rentan_tidak = 0.541666667
p10_cukuprentan_ya = 0.473684211
p10_cukuprentan_tidak = 0.270833333
p10_tidakrentan_ya = 0.526315789
p10_tidakrentan_tidak = 0.1875

#deklarasi nilai P|C pada parameter 11/tingkat keparahan persepsi
p11_parah_ya = 0.052631579
p11_parah_tidak = 0.645833333
p11_tidakparah_ya = 0.947368421
p11_tidakparah_tidak = 0.354166667

#deklarasi nilai P|C pada parameter 12/kekuatan motivasi
p12_kuat_ya = 0.473684211
p12_kuat_tidak = 0.916666667
p12_sedang_ya = 0.210526316
p12_sedang_tidak = 0.083333333
p12_lemah_ya = 0.315789474
p12_lemah_tidak = 0

#deklarasi nilai P|C pada parameter 13/kesediaan motivasi
p13_ya_ya = 0.263157895
p13_ya_tidak = 0.5625
p13_kurang_ya = 0.105263158
p13_kurang_tidak = 0.354166667
p13_tidak_ya = 0.631578947
p13_tidak_tidak = 0.083333333

#deklarasi nilai P|C pada parameter 14/dukungan sosial emosionalitas
p14_sangatbaik_ya = 0.105263158
p14_sangatbaik_tidak = 0.479166667
p14_baik_ya = 0.315789474
p14_baik_tidak =  0.229166667
p14_kurang_ya =  0.578947368 
p14_kurang_tidak = 0.291666667

#deklarasi nilai P|C pada parameter 15/apresiasi dukungan sosial
p15_baik_ya = 0.421052632
p15_baik_tidak =  0.6875
p15_tidakbaik_ya = 0.578947368
p15_tidakbaik_tidak = 0.3125

#deklarasi nilai P|C pada parameter 16/dukungan sosial instrimental
p16_sangatbaik_ya =  0.473684211
p16_sangatbaik_tidak =  0.625
p16_baik_ya =  0.263157895
p16_baik_tidak =  0.1875
p16_kurang_ya = 0.263157895
p16_kurang_tidak = 0.1875

#deklarasi nilai P|C pada parameter 17/pemberdayaan pengetahuan
p17_sangatbaik_ya =  0.210526316
p17_sangatbaik_tidak =  0.770833333
p17_baik_ya =  0.368421053
p17_baik_tidak = 0.041666667
p17_kurang_ya = 0.421052632
p17_kurang_tidak =  0.1875

#deklarasi nilai P|C pada parameter 18/kemampuan pemberdayaan
p18_sangatbaik_ya = 0.052631579
p18_sangatbaik_tidak =  0.5625
p18_baik_ya = 0.315789474
p18_baik_tidak = 0.3125
p18_kurang_ya =  0.631578947
p18_kurang_tidak =  0.125

#deklarasi nilai P|C pada parameter 19/keinginan pemberdayaan
p19_tinggi_ya = 0.263157895
p19_tinggi_tidak =  0.708333333
p19_sedang_ya = 0.263157895
p19_sedang_tidak =  0.145833333
p19_rendah_ya =  0.473684211
p19_rendah_tidak = 0.145833333

pilihan1 = [
    ("Ya", 1),
    ("Tidak", 2),
    ]

pilihan2 = [
    ("Ya", 1),
    ("Tidak Terlalu", 2),
    ("Tidak", 3),
    ]

pilihan3 = [
    ("Ya", 1),
    ("Tidak Terlalu", 2),
    ]
 
 
class sp:
    def __init__(self, parent, title):
        self.parent = parent
        
        self.parent.title(title)
        self.parent.protocol("WM_DELETE_WINDOW", self.onTutup)

        self.parent.geometry("1000x750")
         
        self.aturKomponen()
        
         
    def aturKomponen(self):
        mainFrame = tk.Frame(self.parent, bd=5)
        mainFrame.pack(fill=tk.BOTH, expand=1)

        fr_top = tk.Frame(mainFrame, bd=5)
        fr_top.pack(fill=BOTH, expand=YES, side=TOP)

        fr_bawah = tk.Frame(mainFrame, bd=5)
        fr_bawah.pack(fill=BOTH, expand=YES, side=BOTTOM)

        fr_kanan = tk.Frame(mainFrame, bd=5)
        fr_kanan.pack(fill=BOTH, expand=YES, side=RIGHT)

        fr_kiri = tk.Frame(mainFrame, bd=5)
        fr_kiri.pack(fill=BOTH, expand=YES, side=LEFT)

        fr_kawah = tk.Frame(fr_bawah)
        fr_kawah.pack(side=RIGHT, expand=YES, anchor=W)

        fr_kirih = tk.Frame(fr_bawah)
        fr_kirih.pack(side=LEFT, expand=YES, anchor=E)

        fr_kkiri1 = tk.Frame(fr_kiri)
        fr_kkiri1.pack(fill=BOTH, expand=YES, side=LEFT)

        fr_kkiri2 = tk.Frame(fr_kiri)
        fr_kkiri2.pack(fill=BOTH, expand=YES, side=RIGHT)

        lb1 = tk.Label(fr_top, text="Selamat Datang Di Sistem Prediksi Penyakit Kanker Serviks?", anchor=tk.W)
        lb1.pack()
        lb2 = tk.Label(fr_top, text="Silahkan jawab dengan memilih salah satu jawaban yang tersedia dari setiap pertanyaan ? \n \n", anchor=tk.W)
        lb2.pack()
         
        lblSoal1 = tk.Label(fr_kkiri1, text="1. Apakah anda berganti pasangan lebih dari sekali dalam satu bulan ?", anchor=tk.W) 
        lblSoal1.pack(fill=tk.X)
        self.nilai = tk.IntVar()      
        for teks, dat in pilihan1:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai, value=dat)
            pilihan.pack(anchor=tk.W)
             
        lblSoal2 = tk.Label(fr_kkiri1, text="2. Apakah anda memiliki kebiasaan makan yang buruk ? (sering \nmemakan junk food/jarang makan buah/jarang makan sayur)", anchor=tk.W)
        lblSoal2.pack(fill=tk.X)
        self.nilai2 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai2, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal3 = tk.Label(fr_kkiri1, text="3. Apakah anda adalah seseorang yang hidup higenis, seperti \n membersihkan badan setelah usai berhubungan seksual ? ", anchor=tk.W)
        lblSoal3.pack(fill=tk.X)
        self.nilai3 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai3, value=dat)
            pilihan.pack(anchor=tk.W)
        
        lblSoal4 = tk.Label(fr_kkiri1, text="4. Apakah anda memiliki niat yang kuat untuk terhindar dari penyakit ini ?", anchor=tk.W)
        lblSoal4.pack(fill=tk.X)
        self.nilai4 = tk.IntVar()      
        for teks, dat in pilihan3:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai4, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal5 = tk.Label(fr_kkiri1, text="5. Apakah anda berkomitmen dengan niat anda ?", anchor=tk.W)
        lblSoal5.pack(fill=tk.X)
        self.nilai5 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai5, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal6 = tk.Label(fr_kkiri1, text="6. Apakah anda konsisten dengan sikap anda ?", anchor=tk.W)
        lblSoal6.pack(fill=tk.X)
        self.nilai6 = tk.IntVar()      
        for teks, dat in pilihan3:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai6, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal7 = tk.Label(fr_kkiri1, text="7. Apakah anda biasanya melakukan sesuatu\nsecara spontan/berdasarkan dorongan hati ?", anchor=tk.W)
        lblSoal7.pack(fill=tk.X)
        self.nilai7 = tk.IntVar()      
        for teks, dat in pilihan1:
            pilihan = tk.Radiobutton(fr_kkiri1, text=teks, variable=self.nilai7, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal8 = tk.Label(fr_kkiri2, text="8. Apakah menurut anda norma norma yang ada itu penting ?", anchor=tk.W)
        lblSoal8.pack(fill=tk.X)
        self.nilai8 = tk.IntVar()      
        for teks, dat in pilihan1:
            pilihan = tk.Radiobutton(fr_kkiri2, text=teks, variable=self.nilai8, value=dat)
            pilihan.pack(anchor=tk.W)
        
        lblSoal9 = tk.Label(fr_kkiri2, text="9. Menurut anda, apakah anda memenuhi norma yang ada lingkungan sekitar anda ?", anchor=tk.W)
        lblSoal9.pack(fill=tk.X)
        self.nilai9 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri2, text=teks, variable=self.nilai9, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal10 = tk.Label(fr_kkiri2, text="10. Apakah anda memiliki kerentanan persepsi atau \n persepsi subjektif dari resiko tertular penyakit ?", anchor=tk.W)
        lblSoal10.pack(fill=tk.X)
        self.nilai10 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri2, text=teks, variable=self.nilai10, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal11 = tk.Label(fr_kkiri2, text="11. Apakah tingkat keparahan persepsi tersebut tinggi pada anda ?", anchor=tk.W)
        lblSoal11.pack(fill=tk.X)
        self.nilai11 = tk.IntVar()      
        for teks, dat in pilihan1:
            pilihan = tk.Radiobutton(fr_kkiri2, text=teks, variable=self.nilai11, value=dat)
            pilihan.pack(anchor=tk.W)
        
        lblSoal12 = tk.Label(fr_kkiri2, text="12. Apakah anda memiliki motivasi yang kuat untuk terhindar dari penyakit ini ?", anchor=tk.W)
        lblSoal12.pack(fill=tk.X)
        self.nilai12 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri2, text=teks, variable=self.nilai12, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal13 = tk.Label(fr_kkiri2, text="13. Apakah anda memiliki motivasi terhadap diri anda untuk terhindar dari penyakit ini ?", anchor=tk.W)
        lblSoal13.pack(fill=tk.X)
        self.nilai13 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kkiri2, text=teks, variable=self.nilai13, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal14 = tk.Label(fr_kanan, text="14. Apakah anda mendapatkan dukungan emosional ? (baik dari keluarga, kerabat, dan lainnya)", anchor=tk.W)
        lblSoal14.pack(fill=tk.X)
        self.nilai14 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kanan, text=teks, variable=self.nilai14, value=dat)
            pilihan.pack(anchor=tk.W)
        
        lblSoal15 = tk.Label(fr_kanan, text="15. Apakah anda mengapresiasi dukungan sosial tersebut ?", anchor=tk.W)
        lblSoal15.pack(fill=tk.X)
        self.nilai15 = tk.IntVar()      
        for teks, dat in pilihan1:
            pilihan = tk.Radiobutton(fr_kanan, text=teks, variable=self.nilai15, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal16 = tk.Label(fr_kanan, text="16. Apakah anda mendapatkan dukungan secara langsung atau bersifat \n fasilitas (Seperti meminjamkan uang atau memberikan makanan) ?", anchor=tk.W)
        lblSoal16.pack(fill=tk.X)
        self.nilai16 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kanan, text=teks, variable=self.nilai16, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal17 = tk.Label(fr_kanan, text="17. Apakah anda melakukan pemberdayaan pada pengetahuan anda ?", anchor=tk.W)
        lblSoal17.pack(fill=tk.X)
        self.nilai17 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kanan, text=teks, variable=self.nilai17, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal18 = tk.Label(fr_kanan, text="18. Apakah anda memiliki kemampuan untuk malakukan pemberdayaan pada diri anda?", anchor=tk.W)
        lblSoal18.pack(fill=tk.X)
        self.nilai18 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kanan, text=teks, variable=self.nilai18, value=dat)
            pilihan.pack(anchor=tk.W)

        lblSoal19 = tk.Label(fr_kanan, text="19. Apakah anda memiliki keinginan untuk malakukan pemberdayaan pada diri anda?", anchor=tk.W)
        lblSoal19.pack(fill=tk.X)
        self.nilai19 = tk.IntVar()      
        for teks, dat in pilihan2:
            pilihan = tk.Radiobutton(fr_kanan, text=teks, variable=self.nilai19, value=dat)
            pilihan.pack(anchor=tk.W)      

        self.btn1 = tk.Button(fr_kirih, text="Prediksi", width=10, command=self.onKlik)
        self.btn1.pack(side=LEFT)
        self.btn2 = tk.Button(fr_kawah, text="Keluar", width=10, command=self.onTutup)
        self.btn2.pack(side=LEFT)
    

    def l2(self, event=None):
        mainFrameee = tk.Frame(self.parent, bd=20)
        mainFrameee.pack(fill=tk.BOTH, expand=1)

       
        lb11 = tk.Label(mainFrameee, text="Selamat Datang Di Sistem Prediksi Penyakit Kanker Serviks ?", anchor=tk.W)
        lb11.pack()

        lb22 = tk.Label(mainFrameee, text="Silahkan jawab dengan memilih salah satu jawaban yang tersedia dari setiap pertanyaan ? \n \n", anchor=tk.W)
        lb22.pack()
            
    
    def onTutup(self, event=None):
        self.parent.destroy()
         
    def onKlik(self, event=None):
        jawab1 = self.nilai.get()
        if jawab1 == 1:
            a1 = p1_beresiko_ya
            a2 = p1_beresiko_tidak
        elif jawab1 == 2:
            a1 = p1_tidakberesiko_ya
            a2 = p1_tidakberesiko_tidak

        jawab2 = self.nilai2.get()
        if jawab2 == 1:
            b1 = p2_beresiko_ya
            b2 = p2_beresiko_tidak
        elif jawab2 == 2:
            b1 = p2_kurangberesiko_ya
            b2 = p2_kurangberesiko_tidak
        elif jawab2 == 3:
            b1 = p2_tidakberesiko_ya
            b2 = p2_tidakberesiko_tidak

        jawab3 =self.nilai3.get()
        if jawab3 == 1:
            c1 = p3_ya_ya
            c2 = p3_ya_tidak
        elif jawab3 == 2:
            c1 = p3_kurang_ya
            c2 = p3_kurang_tidak
        elif jawab3 == 3:
            c1 = p3_tidak_ya
            c2 = p3_tidak_tidak

        jawab4 = self.nilai4.get()
        if jawab4 == 1:
            d1 = p4_tinggi_ya
            d2 = p4_tinggi_tidak
        elif jawab4 == 2:
            d1 = p4_rendah_ya
            d2 = p4_rendah_tidak

        jawab5 = self.nilai5.get()
        if jawab5 == 1:
            e1 = p5_baik_ya
            e2 = p5_baik_tidak
        elif jawab5 == 2:
            e1 = p5_kurang_ya
            e2 = p5_kurang_tidak
        elif jawab5 == 3:
            e1 = p5_rendah_ya
            e2 = p5_rendah_tidak

        jawab6 = self.nilai6.get()
        if jawab6 == 1:
            f1 = p6_baik_ya
            f2 = p6_baik_tidak
        elif jawab6 == 2:
            f1 = p6_buruk_ya
            f2 = p6_buruk_tidak

        jawab7 = self.nilai7.get()
        if jawab7 == 1:
            g1 = p7_baik_ya
            g2 = p7_baik_tidak
        elif jawab7 == 2:
            g1 = p7_buruk_ya
            g2 = p7_buruk_tidak

        jawab8 = self.nilai8.get()
        if jawab8 == 1:
            h1 = p8_tinggi_ya
            h2 = p8_tinggi_tidak
        elif jawab8 == 2:
            h1 = p8_rendah_ya
            h2 = p8_rendah_tidak

        jawab9 = self.nilai9.get()
        if jawab9 == 1:
            i1 = p9_baik_ya
            i2 = p9_baik_tidak
        elif jawab9 == 2:
            i1 = p9_cukup_ya
            i2 = p9_cukup_tidak
        elif jawab9 == 3:
            i1 = p9_kurang_ya
            i2 = p9_kurang_tidak

        jawab10 = self.nilai10.get()
        if jawab10 == 1:
            j1 = p10_rentan_ya
            j2 = p10_rentan_tidak
        elif jawab10 == 2:
            j1 = p10_cukuprentan_ya
            j2 = p10_cukuprentan_tidak
        elif jawab10 == 3:
            j1 = p10_tidakrentan_ya
            j2 = p10_tidakrentan_tidak

        jawab11 = self.nilai11.get()
        if jawab11 == 1:
            k1 = p11_parah_ya
            k2 = p11_parah_tidak
        elif jawab11 == 2:
            k1 = p11_tidakparah_ya
            k2 = p11_tidakparah_tidak

        jawab12 = self.nilai12.get()
        if jawab12 == 1:
            l1 = p12_kuat_ya
            l2 = p12_kuat_tidak
        elif jawab12 == 2:
            l1 = p12_sedang_ya
            l2 = p12_sedang_tidak
        elif jawab12 == 3:
            l1 = p12_lemah_ya
            l2 = p12_lemah_tidak

        jawab13 = self.nilai13.get()
        if jawab13 == 1:
            m1 = p13_ya_ya
            m2 = p13_ya_tidak
        elif jawab13 == 2:
            m1 = p13_kurang_ya
            m2 = p13_kurang_tidak
        elif jawab13 == 3:
            m1 = p13_tidak_ya
            m2 = p13_tidak_tidak

        jawab14 = self.nilai14.get()
        if jawab14 == 1:
            n1 = p14_sangatbaik_ya
            n2 = p14_sangatbaik_tidak
        elif jawab14 == 2:
            n1 = p14_baik_ya
            n2 = p14_baik_tidak
        elif jawab14 == 3:
            n1 = p14_kurang_ya
            n2 = p14_kurang_tidak

        jawab15 = self.nilai15.get()
        if jawab15 == 1:
            o1 = p15_baik_ya
            o2 = p15_baik_tidak
        elif jawab15 == 2:
            o1 = p15_tidakbaik_ya
            o2 = p15_tidakbaik_tidak

        jawab16 = self.nilai16.get()
        if jawab16 == 1:
            p1 = p16_sangatbaik_ya
            p2 = p16_sangatbaik_tidak
        elif jawab16 == 2:
            p1 = p16_baik_ya
            p2 = p16_baik_tidak
        elif jawab16 == 3:
            p1 = p16_kurang_ya
            p2 = p16_kurang_tidak

        jawab17 = self.nilai17.get()
        if jawab17 == 1:
            q1 = p17_sangatbaik_ya
            q2 = p17_sangatbaik_tidak
        elif jawab17 == 2:
            q1 = p17_baik_ya
            q2 = p17_baik_tidak
        elif jawab17 == 3:
            q1 = p17_kurang_ya
            q2 = p17_kurang_tidak

        jawab18 = self.nilai18.get()
        if jawab18 == 1:
            r1 = p18_sangatbaik_ya
            r2 = p18_sangatbaik_tidak
        elif jawab18 == 2:
            r1 = p18_baik_ya
            r2 = p18_baik_tidak
        elif jawab18 == 3:
            r1 = p18_kurang_ya
            r2 = p18_kurang_tidak

        jawab19 = self.nilai19.get()
        if jawab19 == 1:
            s1 = p19_tinggi_ya
            s2 = p19_tinggi_tidak
        elif jawab19 == 2:
            s1 = p19_sedang_ya
            s2 = p19_sedang_tidak
        elif jawab19 == 3:
            s1 = p19_rendah_ya
            s2 = p19_rendah_tidak


        self.jumlah = tk.IntVar()
        jumlaha =self.jumlah.get()
        jumlahb =self.jumlah.get()
        jumlaha = a1*b1*c1*d1*e1*f1*g1*h1*i1*j1*k1*l1*m1*n1*o1*p1*q1*r1*s1
        jumlahb = a2*b2*c2*d2*e2*f2*g2*h2*i2*j2*k2*l2*m2*n2*o2*p2*q2*r2*s2
        if jumlaha > jumlahb:
            lbcontoh = tk.Label(text="Anda di prediksi mengidap penyakit kanker serviks")
            lbcontoh.pack()
            print(jumlaha)
            print(jumlahb)
        elif jumlahb > jumlaha:
            lbcontoh = tk.Label(text="Anda di prediksi tidak mengidap kanker serviks")
            lbcontoh.pack()
            print(jumlaha)
            print(jumlahb)
        
    
         
if __name__ == '__main__':
    root = tk.Tk()
     
    aplikasi = sp(root, "Sistem Prediksi Penyakit Kanker Serviks")
     
    root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18872/4042590365.py in <module>
#     571     aplikasi = sp(root, "Sistem Prediksi Penyakit Kanker Serviks")
#     572
# --> 573     root.mainloop()
#
# c:\Users\User\anaconda3\lib\tkinter\__init__.py in mainloop(self, n)
#    1427     def mainloop(self, n=0):
#    1428         """Call the mainloop of Tk."""
# -> 1429         self.tk.mainloop(n)
#    1430
#    1431     def quit(self):
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
